# %% [markdown]
# # Data Visualization Assignment

# %% [markdown]
# ### In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.
# ### Hint:
# ### import numpy as np
# ### import matplotlib.pyplot as plt
# ### from mpl_toolkits.mplot3d import Axes3D from sklearn import decomposition
# ### from sklearn import datasets

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
from sklearn import decomposition
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %% [markdown]
# ### Create the figure

# %%
X_reduced = PCA(n_components=3).fit_transform(iris.data)
Y = iris.target
fig = plt.figure(figsize = (8,8))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(X_reduced[:,0],X_reduced[:,1],X_reduced[:,2],c=Y, cmap=plt.cm.rainbow_r)
ax.set_xlabel('1st eigenvector', fontsize = 15)
ax.set_ylabel('2nd eigenvector', fontsize = 15)
ax.set_zlabel('3rd eigenvector', fontsize = 15)
ax.set_title('3 PCA Directions', fontsize = 20)

plt.show()
